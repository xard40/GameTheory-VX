# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Get the season number from the user
try:
  season_number = int(input("Enter the season number: "))
except ValueError:
  print("Invalid season number. Please enter an integer.")
  exit()

# Get the 100 numbers as a string from the user
numbers_str = input("Enter 100 numbers separated by spaces: ")

# Convert the string to a list of numbers
try:
  numbers = [int(x) for x in numbers_str.split()]
  if len(numbers) != 100:
    raise ValueError("Please enter exactly 100 numbers.")
except ValueError as e:
  print(f"Invalid input: {e}")
  exit()

# Create a Pandas DataFrame
new_data = {'ID': numbers}
new_df = pd.DataFrame(new_data)

# Create the histogram
plt.figure(figsize=(10, 6))
plt.hist(new_df['ID'], bins=30, edgecolor='black')

# Add labels and title
plt.title(f'Distribution of Season {season_number}')
plt.xlabel('ID')
plt.ylabel('Frequency')
plt.show()
# Out:
# Enter the season number: 40
# Enter 100 numbers separated by spaces: 5785 2773 4243 1144 261 4092 4725 1905 10070 308 3881 3863 425 1268 4192 7042 12815 10047 56 9995 4234 533 3405 297 9993 2913 1210 3905 12356 8669 4004 114 174 2049 9656 3992 3379 4229 52 10001 11421 1362 5793 3926 11642 2342 2252 12493 3748 2298 9270 9614 3928 3746 4237 6774 10085 10221 10431 9815 10412 4258 1065 799 4434 9904 10161 2951 9572 11728 2393 1047 3337 4297 1903 1045 3519 12782 7611 4600 1707 2631 10331 1034 10237 3993 3191 3998 3765 3886 4511 3783 3968 4338 393 9176 1005 2190 3842 8184

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Get the season number from the user
try:
  season_number = int(input("Enter the season number: "))
except ValueError:
  print("Invalid season number. Please enter an integer.")
  exit()

# Get the 100 numbers as a string from the user
numbers_str = input("Enter 100 numbers separated by spaces: ")

# Convert the string to a list of numbers
try:
  numbers = [int(x) for x in numbers_str.split()]
  if len(numbers) != 100:
    raise ValueError("Please enter exactly 100 numbers.")
except ValueError as e:
  print(f"Invalid input: {e}")
  exit()

# Create a Pandas DataFrame
new_data = {'ID': numbers}
new_df = pd.DataFrame(new_data)

# Create the histogram
plt.figure(figsize=(10, 6))
plt.hist(new_df['ID'], bins=30, edgecolor='black')

# Add labels and title
plt.title(f'Distribution of Season {season_number}')
plt.xlabel('ID')
plt.ylabel('Frequency')
plt.show()
# Out:
# Enter the season number: 41
# Enter 100 numbers separated by spaces: 5082 1491 2011 1345 5182 4857 9281 7936 9903 571 8669 8717 9522 1953 9010 4709 565 705 2987 3191 2704 1032 10366 7854 10315 7010 10878 174 8751 11031 9656 3675 846 2637 2238 10370 4878 2967 1451 3559 10500 3284 10210 5066 8854 2499 2951 10001 5087 3154 1379 10047 9631 7886 8270 11414 3403 2477 8836 643 8686 875 2749 5675 1905 2252 1268 2298 10161 1042 11064 2390 80 7773 182 242 8126 1917 12480 114 1817 1362 1065 317 2305 3626 1676 23 1456 1236 1506 2803 1024 3064 1276 1047 8933 2062 799 2945

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Get the season number from the user
try:
  season_number = int(input("Enter the season number: "))
except ValueError:
  print("Invalid season number. Please enter an integer.")
  exit()

# Get the 100 numbers as a string from the user
numbers_str = input("Enter 100 numbers separated by spaces: ")

# Convert the string to a list of numbers
try:
  numbers = [int(x) for x in numbers_str.split()]
  if len(numbers) != 100:
    raise ValueError("Please enter exactly 100 numbers.")
except ValueError as e:
  print(f"Invalid input: {e}")
  exit()

# Create a Pandas DataFrame
new_data = {'ID': numbers}
new_df = pd.DataFrame(new_data)

# Create the histogram
plt.figure(figsize=(10, 6))
plt.hist(new_df['ID'], bins=30, edgecolor='black')

# Add labels and title
plt.title(f'Distribution of Season {season_number}')
plt.xlabel('ID')
plt.ylabel('Frequency')
plt.show()
# Out:
# Enter the season number: 42
# Enter 100 numbers separated by spaces: 8661 161 4192 1865 5082 2942 1331 2659 3905 4843 11859 12450 9472 5087 4291 11112 1917 3961 3914 10754 12268 12225 2080 9010 11290 4771 4026 1734 5189 6749 14838 557 5137 4562 266 650 3070 4498 437 10194 9771 10831 1309 4995 9810 4857 4866 791 2053 10438 174 4327 4280 12342 3119 4974 11008 3998 4218 1065 244 8371 7818 1032 3800 4293 8489 4204 5459 11258 4811 2322 4241 2849 5065 3269 4341 10370 2835 11113 4275 385 4507 2504 3151 2011 3790 1481 308 3290 9429 4674 4648 12398 881 4637 2693 4548 12205 3111

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Get the season number from the user
try:
  season_number = int(input("Enter the season number: "))
except ValueError:
  print("Invalid season number. Please enter an integer.")
  exit()

# Get the 100 numbers as a string from the user
numbers_str = input("Enter 100 numbers separated by spaces: ")

# Convert the string to a list of numbers
try:
  numbers = [int(x) for x in numbers_str.split()]
  if len(numbers) != 100:
    raise ValueError("Please enter exactly 100 numbers.")
except ValueError as e:
  print(f"Invalid input: {e}")
  exit()

# Create a Pandas DataFrame
new_data = {'ID': numbers}
new_df = pd.DataFrame(new_data)

# Create the histogram
plt.figure(figsize=(10, 6))
plt.hist(new_df['ID'], bins=30, edgecolor='black')

# Add labels and title
plt.title(f'Distribution of Season {season_number}')
plt.xlabel('ID')
plt.ylabel('Frequency')
plt.show()
# Out:
# Enter the season number: 43
# Enter 100 numbers separated by spaces: 6774 10617 7646 10864 2704 5253 7645 6929 10790 11258 10754 11112 10590 2988 5857 3519 426 1456 3557 3961 8367 23 7628 719 37 10815 7065 5144 268 3705 7500 6 1563 3993 5066 4280 1436 56 1668 1065 7777 10242 1144 8212 4866 397 10878 6833 643 9756 59 10434 114 3524 1709 9610 3447 1707 5603 5235 10765 3243 4192 1734 4878 4062 7018 5803 8214 4293 8190 10566 6884 1506 11079 5516 80 2944 1023 4237 5858 6772 11134 357 3119 10683 1834 3532 6995 3401 4802 3872 243 7599 8740 7115 10284 450 705 1005

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Combine the data into a dictionary
all_seasons_data = {
    'season_40': season_40,
    'season_41': season_41,
    'season_42': season_42,
    'season_43': season_43,
    'season_44': season_44,
    'season_45': season_45
}

# Get the season number from the user to query
season_to_query = input("Enter the season number to display its data (e.g., '40'): ")

# Check if the entered season exists in the data
season_key = f'season_{season_to_query}'

if season_key in all_seasons_data:
  # Get the data for the specified season
  season_data = all_seasons_data[season_key]

  # Create a Pandas DataFrame
  query_data = {'ID': season_data}
  query_df = pd.DataFrame(query_data)

  # Create the histogram
  plt.figure(figsize=(10, 6))
  plt.hist(query_df['ID'], bins=30, edgecolor='black')

  # Add labels and title
  plt.title(f'Distribution of Season {season_to_query}')
  plt.xlabel('ID')
  plt.ylabel('Frequency')
  plt.show()
else:
  print(f"Season {season_to_query} not found in the available data.")
# Out:
# Enter the season number to display its data (e.g., '40'): 45
